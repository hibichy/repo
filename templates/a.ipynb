# %%
from pandasai import SmartDataframe
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from pandasai import SmartDataframe
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandasai/__init__.py:7
#       2 """
#       3 PandasAI is a wrapper around a LLM to make dataframes conversational
#       4 """
#       5 import importlib.metadata
# ----> 7 from .agent import Agent
#       8 from .helpers.cache import Cache
#       9 from .skills import skill
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/pandasai/agent/__init__.py:5
#       2 from typing import List, Optional, Union
#       4 from ..helpers.df_info import DataFrameType
# ----> 5 from ..helpers.logger import Logger
#       6 from ..helpers.memory import Memory
#       7 from ..prompts.base import AbstractPrompt
#
# ...

# %%
import pandas as pd
